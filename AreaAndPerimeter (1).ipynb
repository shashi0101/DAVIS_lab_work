# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/ClassWork/ExceptionHandeling/AgeException.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# custom exception for age
#----------------------------------------------------
class AgeException(Exception):
    pass

try:
    age = int(input("Enter your age: "))

    if age < 0 or age > 120:
        raise AgeException("Invalid Age! Please enter age between 0 and 120.")

    if age >= 18:
        print("You are eligible to vote")
    else:
        print("You are not eligible to vote")

except AgeException as e:
    print("Error:", e)

except ValueError:
    print("Please enter a valid number!")
# Out:
# Enter your age: -17
# Error: Invalid Age! Please enter age between 0 and 120.
