# %% [markdown]
# <a href="https://colab.research.google.com/github/shashi0101/DAVIS_lab_work/blob/main/ClassWork/Exception%20Handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  num1=float(input("Enter first number:"))
  num1=float(input("Enter Second number:"))
  #---------------------------------------
  print("----------------------------")
  print("On Dividing",num1,"By",num2)
  print("quotient:",(num1/num2))
  print("----------------------------")
except ValueError:
  print("Unexpected data type")
except ZeroDivisionError:
  print("Unable to Divide by 0")
else:
  print("----------------------------")
finally:
  print("---------Program Executed--------")
