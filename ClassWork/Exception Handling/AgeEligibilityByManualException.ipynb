# %% [markdown]
# <a href="https://colab.research.google.com/github/shashi0101/DAVIS_lab_work/blob/main/ClassWork/Exception%20Handling/AgeEligibilityByManualException.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  age=float(input("Enter age:"))
  #---------------------------------------
  print("----------------------------")
  if(age>18):
    print("Eligible for Voting")
  elif(age<0):
    raise AgeException()

  else:
    print("not Eligible for Voting")
except ValueError:
  print("Unexpected data type")
except AgeException:
    print("enter a valid age")

else:
  print("----------------------------")
finally:
  print("---------Program Executed--------")
