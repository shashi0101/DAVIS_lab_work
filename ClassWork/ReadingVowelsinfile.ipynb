# %% [markdown]
# <a href="https://colab.research.google.com/github/shashi0101/DAVIS_lab_work/blob/main/ClassWork/ReadingVowelsinfile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
vowels = "aeiouAEIOU"
count = 0

filev=open("firstfile.txt", "r")
for line in filev:
        for char in line:
            if char in vowels:
                count += 1

print(f"Total vowels found: {count}")
# Out:
# Total vowels found: 0
