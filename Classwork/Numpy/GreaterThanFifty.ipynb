# %% [markdown]
# <a href="https://colab.research.google.com/github/shashi0101/DAVIS_lab_work/blob/main/Classwork/Numpy/GreaterThanFifty.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
# to create array
data = np.array([20,30,70,90])
print(data)
#------------------------------------
print("element greater than 50:")
print(data>50)
print("-----------------------------------")
#dividing each element by 5
numbers2 = data/5
print("After dividing each element by 5: ")
print(numbers2)
# Out:
# [20 30 70 90]
# element greater than 50:
# [False False  True  True]
# -----------------------------------
# After dividing each element by 5:
# [ 4.  6. 14. 18.]
