# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/ClassWork/ForLoopInPython/PatternPrinting(Classwork_27thMarch).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Pattern printing
#-------------------------------------------
rows = int(input("no. of rows:"))
for i in range(1,rows+1):
  print(" " * (rows-i) + "*" * i)
# Out:
# no. of rows:5
#     *
#    **
#   ***
#  ****
# *****
