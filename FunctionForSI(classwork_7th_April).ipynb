# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/ClassWork/ForLoopInPython/evenFactors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# input a number
num = int(input("Enter a number: "))

print("Even factors are:")
#-----------------------------------------------
for i in range(1, num + 1):
    if num % i == 0:
        if i % 2 == 0:
            print(i)
# Out:
# Enter a number: 12
# Even factors are:
# 2
# 4
# 6
# 12
