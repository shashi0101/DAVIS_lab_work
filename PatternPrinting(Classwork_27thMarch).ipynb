# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/ClassWork/FileHandeling/filewriting2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# program for writing data into files
# opening file for write operation
filev = open("firstfile.txt", "w")
# blank list of sentences
sentences = []
# writing five sentence into the file
print ("Enter any five sentences:")
for x in range(5):
    # input of data from user
    sentence = input()
    # inserting sentences in to the list
    sentences.append(sentence)
    print("---------------------------------------")
    # writing data into file
    filev.writelines(sentence)
print("Data seccesfully written")
# closing the file
filev.close()
# Out:
# Enter any five sentences:
# Hello
# ---------------------------------------
# hello
# ---------------------------------------
# python
# ---------------------------------------
# PHYTHON
# ---------------------------------------
# Hii
# ---------------------------------------
# Data seccesfully written
