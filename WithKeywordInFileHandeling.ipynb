# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/ClassWork/ExceptionHandeling/DivisionByZero.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    num1 = float(input("Enter first number: "))
    num2 = float(input("Enter second number: "))
#-----------------------------------------------
    print("--------------------------------------")
    print("on dividing ",num1,"by",num2)
    print("Quotient:", num1/num2)
    print("-------------------------------------------")
except ValueError:
    print("Unexpected data type")
except ZeroDivisionError:
    print("Unable to divide by zero")
else:
    print("--------------------------------------------")
finally:
    print("----------------Program executed----------------")
# Out:
# Enter first number: 5
# Enter second number: 0
# --------------------------------------
# on dividing  5.0 by 0.0
# Unable to divide by zero
# ----------------Program executed----------------
