# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/ClassWork/FileHandeling/AreaAndPerimeter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Read radius from file
with open("input.txt", "r") as f:
    r = float(f.read())

# Calculate area and perimeter
area = 3.14 * r * r
perimeter = 2 * 3.14 * r

# Write result to another file
with open("output.txt", "w") as f:
    f.write("Area = " + str(area) + "\n")
    f.write("Perimeter = " + str(perimeter))

print("Result written to file.")
