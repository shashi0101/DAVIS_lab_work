# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/ClassWork/FileHandeling/WithKeywordInFileHandeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# file handeling using with keyword
#----------------------------------------------------
# Open source file in read mode
with open("source.txt", "r") as src:
    content = src.read()

# Open destination file in write mode
with open("destination.txt", "w") as dest:
    dest.write(content)

print("File copied successfully.")
