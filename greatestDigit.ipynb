# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/ClassWork/IfElseInPython/FactorialOfNumber.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# To find out factorial of a number

num = int(input("Enter any number:"))
if(num<0):
  print("Factorial not possible")
elif(num==0):
  print("Factorial = 1")
else:
  fact = 1
  for x in range(1,num+1):
    fact = fact*x
  print("Factorial=", fact)
# Out:
# Enter any number:5
# Factorial= 120
