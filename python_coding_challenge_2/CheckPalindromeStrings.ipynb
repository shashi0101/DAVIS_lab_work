# %% [markdown]
# <a href="https://colab.research.google.com/github/shashi0101/DAVIS_lab_work/blob/main/python_coding_challenge_2/CheckPalindromeStrings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def is_palindrome(input_string):

   # Checks if a given string is a palindrome (case-insensitive, ignoring non-alphanumeric characters).


    # Normalize the string: convert to lowercase and remove non-alphanumeric characters
    cleaned_string = ''.join(char.lower() for char in input_string if char.isalnum())

    # Compare the cleaned string with its reverse
    if cleaned_string == cleaned_string[::-1]:
        return "Yes"
    else:
        return "No"

# main function
input = "madam"
output = is_palindrome(input)
print(f"Input: \"{input}\"")
print(f"Output: {output}")
# Out:
# Input: "madam"
# Output: Yes
