# %% [markdown]
# <a href="https://colab.research.google.com/github/shashi0101/DAVIS_lab_work/blob/main/python_coding_challenge_2/Converter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def list_to_tuple(input_list):
    # Use the built-in tuple() constructor to convert the list
    return tuple(input_list)

# Example usage:
input_list_1 = [1, 2, 3]
output_1 = list_to_tuple(input_list_1)
print(f"Input: {input_list_1}")
print(f"Output (Tuple): {output_1}")
print(f"Type of output: {type(output_1)}")
