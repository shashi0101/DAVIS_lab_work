# %% [markdown]
# <a href="https://colab.research.google.com/github/shashi0101/DAVIS_lab_work/blob/main/python_coding_challenge_2/RemoveDuplicateEntries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def remove_duplicates(input_list):
    # Convert the list to a set to remove duplicates
    unique_elements = set(input_list)
    # Convert the set back to a list
    return list(unique_elements)

# main function
input_list_1 = [1, 1, 2, 3]
output_list_1 = remove_duplicates(input_list_1)
print(f"Input: {input_list_1}")
print(f"Output: {output_list_1}")
