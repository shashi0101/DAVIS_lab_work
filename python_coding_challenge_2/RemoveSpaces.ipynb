# %% [markdown]
# <a href="https://colab.research.google.com/github/shashi0101/DAVIS_lab_work/blob/main/python_coding_challenge_2/RemoveSpaces.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#function to remove spaces
def remove_spaces(input_string):

   # Removes all spaces from a given string.


    return input_string.replace(" ", "")

# main function
input_str_1 = "hello world"
output_no_spaces_1 = remove_spaces(input_str_1)
print(f"Input: \"{input_str_1}\"")
print(f"Output: \"{output_no_spaces_1}\"")
# Out:
# Input: "hello world"
# Output: "helloworld"
