# %% [markdown]
# <a href="https://colab.research.google.com/github/shashi0101/DAVIS_lab_work/blob/main/python_coding_challenge_2/ValidatesPalindromeNumber.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#calculate palindrome numbers
def is_palindrome_number(n):

    #Checks if a number is a palindrome.


    # Convert the number to a string to easily reverse it
    str_n = str(n)
    # Compare the string with its reversed version
    if str_n == str_n[::-1]:
        return "Palindrome"
    else:
        return "Not a Palindrome"

# main function
input_num_1 = 121
output_palindrome_1 = is_palindrome_number(input_num_1)
print(f"Input: {input_num_1}")
print(f"Output: {output_palindrome_1}")
# Out:
# Input: 121
# Output: Palindrome
